# %%
# !pip install -q simpletransformers

from simpletransformers.ner import NERModel
import pandas as pd

data = pd.read_csv("/content/drive/MyDrive/NER Constructs Only/Infer_data.csv")
abstracts = data["Abstract"].tolist()

model = NERModel( 'bert', '//content/drive/MyDrive/NER Constructs Only/models/best_model')
predictions, _ = model.predict(abstracts)


entities = []
for idx in range(len(data)): 
    pred = predictions[idx]
    res = []
    for entity in pred:
        if "O" not in entity.values(): 
            res.append(entity)
    entities.append(res)

data["Entities"] = entities
data.to_csv("/content/drive/MyDrive/FR/NER/data_with_NER.csv", index = False)
data.head()
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# Running Prediction:   0%|          | 0/1188 [00:00<?, ?it/s]
#                                              Authors  \
# 0                    Zhu H., Pan Y., Qiu J., Xiao J.
# 1         Liu X., Greenbaum R.L., Allen D., Zhang Z.
# 2                           Wang Y., Xiao S., Ren R.
# 3  Jannat T., Alam S.S., Ho Y.-H., Omar N.A., Lin...
# 4  Adler T.R., Pittz T.G., Strevel H.B., Denney D...
#
#                                                Title  Year  \
# 0  Hometown Ties and Favoritism in Chinese Corpor...  2022
# 1  A Newcomer Socialization Perspective on the Pr...  2022
# 2  A Moral Cleansing Process: How and When Does U...  2022
# 3  Can Corporate Ethics Programs Reduce Unethical...  2022
# 4  Team Over-Empowerment in Market Research: A Vi...  2022
#
#                  Source title Volume Issue Art. No. Page start Page end  \
# 0  Journal of Business Ethics    176     2      NaN        283      310
# 1  Journal of Business Ethics    176     1      NaN         73       88
# 2  Journal of Business Ethics    176     1      NaN        175      193
# 3  Journal of Business Ethics    176     1      NaN         37       53
# 4  Journal of Business Ethics    176     1      NaN        159      173
#
#   Page count Cited by                         DOI  \
# 0        NaN        2  10.1007/s10551-020-04711-1
# 1        NaN      NaN  10.1007/s10551-020-04730-y
# 2        NaN        2  10.1007/s10551-020-04697-w
# 3        NaN        1  10.1007/s10551-020-04726-8
# 4        NaN        1  10.1007/s10551-020-04702-2
#
#                                                 Link  \
# 0  https://www.scopus.com/inward/record.uri?eid=2...
# 1  https://www.scopus.com/inward/record.uri?eid=2...
# 2  https://www.scopus.com/inward/record.uri?eid=2...
# 3  https://www.scopus.com/inward/record.uri?eid=2...
# 4  https://www.scopus.com/inward/record.uri?eid=2...
#
#                                             Abstract  \
# 0  This paper provides a systematic analysis of h...
# 1  Drawing on conservation of resources theory, w...
# 2  In this study, we draw on moral cleansing theo...
# 3  While a corporate ethics program is expected t...
# 4  Few scholars have investigated the considerati...
#
#                                      Author Keywords Index Keywords  \
# 0  CEO dismissals; China; Corporate social respon...            NaN
# 1  Coaching; Goal orientation; Newcomer socializa...            NaN
# 2  Felt guilt; Moral cleansing theory; Moral iden...            NaN
# 3  Bangladesh; Coping appraisal; Corporate ethics...            NaN
# 4   Market research; Team empowerment; Virtue ethics            NaN
#
#                       Open Access  \
# 0                             NaN
# 1          All Open Access, Green
# 2  All Open Access, Bronze, Green
# 3                             NaN
# 4                             NaN
#
#                                             Entities
# 0  [{'hometown': 'B-THE'}, {'ties,': 'I-THE'}, {'...
# 1  [{'conservation': 'B-THE'}, {'of': 'I-THE'}, {...
# 2  [{'moral': 'B-THE'}, {'cleansing': 'I-THE'}, {...
# 3  [{'corporate': 'B-THE'}, {'ethics': 'I-THE'}, ...
# 4  [{'over-empowered': 'B-THE'}, {'teams': 'I-THE...
